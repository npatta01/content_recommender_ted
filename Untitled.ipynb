# %%
import pandas as pd
import glob
import json
from tqdm import tqdm
import re
from datetime import datetime
import gensim
import logging

# %%
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO  # ipython sometimes messes up the logging setup; restore

# %%
# !pip install pysrt
# Out:
# Collecting pysrt
#   Downloading https://files.pythonhosted.org/packages/f6/33/16ad65a8973cb8bcb494af09ee1b9ab5ffdd6ff300bce5d3ac7d3cb1f2cc/pysrt-1.1.1.tar.gz (104kB)
#     100% |████████████████████████████████| 112kB 2.9MB/s ta 0:00:01
# Requirement already satisfied: chardet in /Users/nidhin/anaconda3/envs/py36/lib/python3.6/site-packages (from pysrt)
# Building wheels for collected packages: pysrt
#   Running setup.py bdist_wheel for pysrt ... done
#   Stored in directory: /Users/nidhin/Library/Caches/pip/wheels/a6/95/51/25db5b533f7c8c3bccf661a7f2bf67caaf893f6f92bb37da33
# Successfully built pysrt
# Installing collected packages: pysrt
# Successfully installed pysrt-1.1.1
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pysrt

# %% [markdown]
# kaggle datasets download -d goweiting/ted-talks-transcript
# Use the Kaggle API to download dataset files.
# https://github.com/Kaggle/kaggle-api
#
# https://www.kaggle.com/goweiting/ted-talks-transcript/data
#
# Doc2vec
# https://medium.com/scaleabout/a-gentle-introduction-to-doc2vec-db3e8c0cce5e

# %%
# !ls -lah /Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/
# Out:
# total 2258448
# drwxr-xr-x     8 nidhin  staff   256B May 17 22:01 .
# drwxr-xr-x     3 nidhin  staff    96B May 17 21:52 ..
# drwxrwxr-x  2533 nidhin  staff    79K Jan 27 06:17 subtitles
# -rw-r--r--     1 nidhin  staff   535M May 17 21:53 ted-talks-transcript.zip
# -rw-r--r--     1 nidhin  staff   773B Jan 27 17:11 tedDirector.stats.csv
# -rw-r--r--     1 nidhin  staff   543M Jan 27 17:12 tedDirector.zip
# -rw-r--r--     1 nidhin  staff   7.3M Jan 27 17:13 ted_metadata_kaggle.csv
# -rw-r--r--     1 nidhin  staff   3.4M Jan 27 17:13 ted_metadata_youtube.csv

# %%
#!unzip /Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/tedDirector.zip

# %%
base_path="/Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/"

# %%
print(f"{base_path}subtitles/*.info.json")
# Out:
# /Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/subtitles/*.info.json

# %%
meta_data_files = glob.glob(f"{base_path}subtitles/*/*.info.json")

# %%
def parse_video_info(metadata):
    keys = ["webpage_url", "view_count", "upload_date", "title", "thumbnail" 
            , "duration" , "dislike_count" , "like_count"
            , "description", "categories" ,"id", "average_rating"
            ]
    
    new_dict = {}
    for key in keys:
        new_dict[key] = metadata.get(key,None)
        
    return new_dict

def get_metadata(meta_data_files) -> pd.DataFrame:
    parsed_metadatas = []
    for file in tqdm(meta_data_files):
        with open(file) as f:
            content = json.load(f)
        
        parsed_metadata = parse_video_info(content)
        parsed_metadatas.append(parsed_metadata)

    return pd.DataFrame(parsed_metadatas)

# %%
metadata_df = get_metadata(meta_data_files)
# Out:
# 100%|██████████| 2531/2531 [00:00<00:00, 3824.04it/s]

# %%
metadata_df.head()
# Out:
#    average_rating               categories  \
# 0        4.729469  [Nonprofits & Activism]
# 1        4.940791        [News & Politics]
# 2        4.554828        [News & Politics]
# 3        4.706122   [Science & Technology]
# 4        4.732777        [Travel & Events]
#
#                                          description  dislike_count  duration  \
# 0  http://www.ted.com When German psychologist In...           14.0       830
# 1  As a child growing up in North Korea, Hyeonseo...         2151.0       735
# 2  http://www.ted.com Every day, in a city the si...           68.0       938
# 3  http://www.ted.com With his team at SENSEable ...           54.0       947
# 4  Almost everything we own and use, at some poin...           96.0       684
#
#             id  like_count                                          thumbnail  \
# 0  Jc2F3-nawnI       193.0   https://i.ytimg.com/vi/Jc2F3-nawnI/hqdefault.jpg
# 1  PdxPCeWw75k    143165.0  https://i.ytimg.com/vi/PdxPCeWw75k/maxresdefau...
# 2  CLWRclarri0       543.0   https://i.ytimg.com/vi/CLWRclarri0/hqdefault.jpg
# 3  CijsvAGU6-c       681.0   https://i.ytimg.com/vi/CijsvAGU6-c/hqdefault.jpg
# 4  j7RsRnYlz7I      1341.0  https://i.ytimg.com/vi/j7RsRnYlz7I/maxresdefau...
#
#                                                title upload_date  view_count  \
# 0  Inge Missmahl brings peace to the minds of Afg...    20100929       20695
# 1          My escape from North Korea | Hyeonseo Lee    20130320     6702386
# 2          Carolyn Steel: How food shapes our cities    20091005      125975
# 3  Carlo Ratti: Architecture that senses and resp...    20110503       78537
# 4   Rose George: Inside the secret shipping industry    20131213      144699
#
#                                    webpage_url
# 0  https://www.youtube.com/watch?v=Jc2F3-nawnI
# 1  https://www.youtube.com/watch?v=PdxPCeWw75k
# 2  https://www.youtube.com/watch?v=CLWRclarri0
# 3  https://www.youtube.com/watch?v=CijsvAGU6-c
# 4  https://www.youtube.com/watch?v=j7RsRnYlz7I

# %%
subtitle_files = glob.glob(f"{base_path}subtitles/*/*.en.vtt")

# %%
subtitle_files[0:2]
# Out:
# ['/Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/subtitles/Jc2F3-nawnI/Jc2F3-nawnI.en.vtt',
#  '/Users/nidhin/.kaggle/datasets/goweiting/ted-talks-transcript/subtitles/PdxPCeWw75k/PdxPCeWw75k.en.vtt']

# %%
def parse_subtitle(file_name) -> str:
    subs = pysrt.open(file_name)
    content = ""
    for s in subs:
        content = content + s.text_without_tags + "\n"
    return content

def get_subtitles(subtitle_files) -> pd.DataFrame :
    parsed_subtitles = []
    for file in tqdm(subtitle_files):
        
        res = re.match('.*/(.*).en.vtt',file)
        talk_id  = res.group(1)
        content = parse_subtitle(file)
        
        parsed_subtitles.append ({'id': talk_id , 'transcript': content})
        
    return pd.DataFrame(parsed_subtitles)

# %%
subtitle_files_df = get_subtitles(subtitle_files)
# Out:
# 100%|██████████| 2490/2490 [00:22<00:00, 108.95it/s]

# %%
subtitle_files_df.head()
# Out:
#             id                                         transcript
# 0  Jc2F3-nawnI  So I want to tell you a story -- an encouragin...
# 1  PdxPCeWw75k  Translator: Joseph Geni\nReviewer: Morton Bast...
# 2  CLWRclarri0  How do you feed a city?\nIt's one of the great...
# 3  CijsvAGU6-c  Good afternoon, everybody.\nI've got something...
# 4  j7RsRnYlz7I  A couple of years ago,\nHarvard Business Schoo...

# %%
len(metadata_df)
# Out:
# 2531

# %%
len(subtitle_files_df)
# Out:
# 2490

# %%
df = pd.merge(metadata_df,subtitle_files_df, on='id')

# %%
datetime.strptime('20100929', '%Y%m%d')
# Out:
# datetime.datetime(2010, 9, 29, 0, 0)

# %%
df.head()
# Out:
#    average_rating               categories  \
# 0        4.729469  [Nonprofits & Activism]
# 1        4.940791        [News & Politics]
# 2        4.554828        [News & Politics]
# 3        4.706122   [Science & Technology]
# 4        4.732777        [Travel & Events]
#
#                                          description  dislike_count  duration  \
# 0  http://www.ted.com When German psychologist In...           14.0       830
# 1  As a child growing up in North Korea, Hyeonseo...         2151.0       735
# 2  http://www.ted.com Every day, in a city the si...           68.0       938
# 3  http://www.ted.com With his team at SENSEable ...           54.0       947
# 4  Almost everything we own and use, at some poin...           96.0       684
#
#             id  like_count                                          thumbnail  \
# 0  Jc2F3-nawnI       193.0   https://i.ytimg.com/vi/Jc2F3-nawnI/hqdefault.jpg
# 1  PdxPCeWw75k    143165.0  https://i.ytimg.com/vi/PdxPCeWw75k/maxresdefau...
# 2  CLWRclarri0       543.0   https://i.ytimg.com/vi/CLWRclarri0/hqdefault.jpg
# 3  CijsvAGU6-c       681.0   https://i.ytimg.com/vi/CijsvAGU6-c/hqdefault.jpg
# 4  j7RsRnYlz7I      1341.0  https://i.ytimg.com/vi/j7RsRnYlz7I/maxresdefau...
#
#                                                title upload_date  view_count  \
# 0  Inge Missmahl brings peace to the minds of Afg...    20100929       20695
# 1          My escape from North Korea | Hyeonseo Lee    20130320     6702386
# 2          Carolyn Steel: How food shapes our cities    20091005      125975
# 3  Carlo Ratti: Architecture that senses and resp...    20110503       78537
# 4   Rose George: Inside the secret shipping industry    20131213      144699
#
#                                    webpage_url  \
# 0  https://www.youtube.com/watch?v=Jc2F3-nawnI
# 1  https://www.youtube.com/watch?v=PdxPCeWw75k
# 2  https://www.youtube.com/watch?v=CLWRclarri0
# 3  https://www.youtube.com/watch?v=CijsvAGU6-c
# 4  https://www.youtube.com/watch?v=j7RsRnYlz7I
#
#                                           transcript
# 0  So I want to tell you a story -- an encouragin...
# 1  Translator: Joseph Geni\nReviewer: Morton Bast...
# 2  How do you feed a city?\nIt's one of the great...
# 3  Good afternoon, everybody.\nI've got something...
# 4  A couple of years ago,\nHarvard Business Schoo...

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t) for t in word_tokenize(articles)]

# %%
# ?text.TfidfVectorizer

# %%
from sklearn.feature_extraction import text
Text=df['transcript'].tolist()
tfidf=text.TfidfVectorizer(input=Text,stop_words="english", tokenizer=LemmaTokenizer())
matrix=tfidf.fit_transform(Text)
#print(matrix.shape)

# %%
### Get Similarity Scores using cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
sim_unigram=cosine_similarity(matrix)

# %%
sim_unigram
# Out:
# array([[ 1.        ,  0.42328378,  0.55359966, ...,  0.49388626,
#          0.53364983,  0.58179026],
#        [ 0.42328378,  1.        ,  0.4507271 , ...,  0.43143527,
#          0.42768029,  0.45480349],
#        [ 0.55359966,  0.4507271 ,  1.        , ...,  0.55640022,
#          0.57594978,  0.61223904],
#        ...,
#        [ 0.49388626,  0.43143527,  0.55640022, ...,  1.        ,
#          0.51827279,  0.5542238 ],
#        [ 0.53364983,  0.42768029,  0.57594978, ...,  0.51827279,
#          1.        ,  0.56661015],
#        [ 0.58179026,  0.45480349,  0.61223904, ...,  0.5542238 ,
#          0.56661015,  1.        ]])

# %%
def get_similar_articles(x):
    return "\n".join(df['title'].loc[x.argsort()[-5:-1]])
df['similar_articles_unigram']=[get_similar_articles(x) for x in sim_unigram]

# %%
df['title'][1]
# Out:
# 'My escape from North Korea | Hyeonseo Lee'

# %%
print (df['similar_articles_unigram'][1])
# Out:
# How I Stopped the Taliban from Shutting Down My School | Sakena Yacoobi | TED Talks
# This is what it's like to go undercover in North Korea | Suki Kim
# The family I lost in North Korea. And the family I gained | Joseph Kim
# What I learned as a prisoner in North Korea | Euna Lee

# %% [markdown]
# # Doc2Vec

# %%
df.iloc[0]
# Out:
# average_rating                                                        4.72947
# categories                                            [Nonprofits & Activism]
# description                 http://www.ted.com When German psychologist In...
# dislike_count                                                              14
# duration                                                                  830
# id                                                                Jc2F3-nawnI
# like_count                                                                193
# thumbnail                    https://i.ytimg.com/vi/Jc2F3-nawnI/hqdefault.jpg
# title                       Inge Missmahl brings peace to the minds of Afg...
# upload_date                                               2010-09-29 00:00:00
# view_count                                                              20695
# webpage_url                       https://www.youtube.com/watch?v=Jc2F3-nawnI
# transcript                  So I want to tell you a story -- an encouragin...
# similar_articles_unigram    Maira Kalman: The illustrated woman\nOne woman...
# Name: 0, dtype: object

# %%
[row["title"]] + row["categories"]
# Out:
# ['My escape from North Korea | Hyeonseo Lee', 'News & Politics']

# %%
talk_corpus = []
for (index,row) in df.iterrows():
    content = gensim.utils.simple_preprocess (row["transcript"])
    #tags = [row["title"], row["id"]] + row["categories"]'
    #tags = [row["title"]] + row["categories"]
    tags = [row["title"]] 
    tg = gensim.models.doc2vec.TaggedDocument(content,tags)
    talk_corpus.append(tg)

# %%
talk_corpus[0]
# Out:
# TaggedDocument(words=['so', 'want', 'to', 'tell', 'you', 'story', 'an', 'encouraging', 'story', 'about', 'addressing', 'desperation', 'depression', 'and', 'despair', 'in', 'afghanistan', 'and', 'what', 'we', 'have', 'learned', 'from', 'it', 'and', 'how', 'to', 'help', 'people', 'to', 'overcome', 'traumatic', 'experiences', 'and', 'how', 'to', 'help', 'them', 'to', 'regain', 'some', 'confidence', 'in', 'the', 'time', 'ahead', 'in', 'the', 'future', 'and', 'how', 'to', 'participate', 'again', 'in', 'everyday', 'life', 'so', 'am', 'jungian', 'psychoanalyst', 'and', 'went', 'to', 'afghanistan', 'in', 'january', 'by', 'chance', 'on', 'an', 'assignment', 'for', 'medica', 'mondiale', 'jung', 'in', 'afghanistan', 'you', 'get', 'the', 'picture', 'afghanistan', 'is', 'one', 'of', 'the', 'poorest', 'countries', 'in', 'the', 'world', 'and', 'percent', 'of', 'the', 'people', 'are', 'illiterate', 'war', 'and', 'malnutrition', 'kills', 'people', 'together', 'with', 'hope', 'you', 'may', 'know', 'this', 'from', 'the', 'media', 'but', 'what', 'you', 'may', 'not', 'know', 'is', 'that', 'the', 'average', 'age', 'of', 'the', 'afghan', 'people', 'is', 'years', 'old', 'which', 'means', 'they', 'grow', 'up', 'in', 'such', 'an', 'environment', 'and', 'repeat', 'myself', 'in', 'years', 'of', 'war', 'so', 'this', 'translates', 'into', 'ongoing', 'violence', 'foreign', 'interests', 'bribery', 'drugs', 'ethnic', 'conflicts', 'bad', 'health', 'shame', 'fear', 'and', 'cumulative', 'traumatic', 'experiences', 'local', 'and', 'foreign', 'military', 'are', 'supposed', 'to', 'build', 'peace', 'together', 'with', 'the', 'donors', 'and', 'the', 'governmental', 'and', 'non', 'governmental', 'organizations', 'and', 'people', 'had', 'hope', 'yes', 'but', 'until', 'they', 'realized', 'their', 'situation', 'worsens', 'every', 'day', 'either', 'because', 'they', 'are', 'being', 'killed', 'or', 'because', 'somehow', 'they', 'are', 'poorer', 'than', 'eight', 'years', 'ago', 'one', 'figure', 'for', 'that', 'percent', 'of', 'the', 'children', 'under', 'the', 'age', 'of', 'five', 'years', 'suffer', 'from', 'malnutrition', 'yet', 'there', 'is', 'hope', 'one', 'day', 'man', 'told', 'me', 'my', 'future', 'does', 'not', 'look', 'brilliant', 'but', 'want', 'to', 'have', 'brilliant', 'future', 'for', 'my', 'son', 'this', 'is', 'picture', 'took', 'in', 'walking', 'on', 'fridays', 'over', 'the', 'hills', 'in', 'kabul', 'and', 'for', 'me', 'it', 'symbolic', 'picture', 'of', 'an', 'open', 'future', 'for', 'young', 'generation', 'so', 'doctors', 'prescribe', 'medication', 'and', 'donors', 'are', 'supposed', 'to', 'bring', 'peace', 'by', 'building', 'schools', 'and', 'roads', 'military', 'collect', 'weapons', 'and', 'depression', 'stays', 'intact', 'why', 'because', 'people', 'don', 'have', 'tools', 'to', 'cope', 'with', 'it', 'to', 'get', 'over', 'it', 'so', 'soon', 'after', 'my', 'arrival', 'had', 'confirmed', 'something', 'which', 'had', 'already', 'known', 'that', 'my', 'instruments', 'come', 'from', 'the', 'heart', 'of', 'modern', 'europe', 'yes', 'however', 'what', 'can', 'wound', 'us', 'and', 'our', 'reaction', 'to', 'those', 'wounds', 'they', 'are', 'universal', 'and', 'the', 'big', 'challenge', 'was', 'how', 'to', 'understand', 'the', 'meaning', 'of', 'the', 'symptom', 'in', 'this', 'specific', 'cultural', 'context', 'after', 'counseling', 'session', 'woman', 'said', 'to', 'me', 'because', 'you', 'have', 'felt', 'me', 'can', 'feel', 'myself', 'again', 'and', 'want', 'to', 'participate', 'again', 'in', 'my', 'family', 'life', 'this', 'was', 'very', 'important', 'because', 'the', 'family', 'is', 'central', 'in', 'afghans', 'social', 'system', 'no', 'one', 'can', 'survive', 'alone', 'and', 'if', 'people', 'feel', 'used', 'worthless', 'and', 'ashamed', 'because', 'something', 'horrible', 'has', 'happened', 'to', 'them', 'then', 'they', 'retreat', 'and', 'they', 'fall', 'into', 'social', 'isolation', 'and', 'they', 'do', 'not', 'dare', 'to', 'tell', 'this', 'evil', 'to', 'other',  ...

# %%
model = gensim.models.Doc2Vec(size = 300, 
                              min_count = 3, 
                              iter = 100)
# Out:
# /Users/nidhin/anaconda3/envs/py36/lib/python3.6/site-packages/gensim/models/doc2vec.py:362: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# /Users/nidhin/anaconda3/envs/py36/lib/python3.6/site-packages/gensim/models/doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
model.build_vocab(talk_corpus)
print("model's vocabulary length:", len(model.wv.vocab))
# Out:
# INFO : collecting all words and their counts
# INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO : collected 56933 word types and 2490 unique tags from a corpus of 2490 examples and 4900563 words
# INFO : Loading a fresh vocabulary
# INFO : min_count=3 retains 30597 unique words (53% of original 56933, drops 26336)
# INFO : min_count=3 leaves 4866741 word corpus (99% of original 4900563, drops 33822)
# INFO : deleting the raw counts dictionary of 56933 items
# INFO : sample=0.001 downsamples 57 most-common words
# INFO : downsampling leaves estimated 3601819 word corpus (74.0% of prior 4866741)
# INFO : estimated required memory for 30597 words and 300 dimensions: 92217300 bytes
# INFO : resetting layer weights
# model's vocabulary length: 30597

# %%
model.train(talk_corpus,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# INFO : training model with 3 workers on 30597 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO : EPOCH 1 - PROGRESS: at 26.06% examples, 937513 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 1 - PROGRESS: at 54.78% examples, 974555 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 1 - PROGRESS: at 83.17% examples, 994522 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 1 : training on 4900563 raw words (3604577 effective words) took 3.6s, 999712 effective words/s
# INFO : EPOCH 2 - PROGRESS: at 27.47% examples, 988633 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 2 - PROGRESS: at 54.22% examples, 965152 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 2 - PROGRESS: at 81.57% examples, 974552 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 2 : training on 4900563 raw words (3604589 effective words) took 3.7s, 984319 effective words/s
# INFO : EPOCH 3 - PROGRESS: at 27.87% examples, 994164 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 3 - PROGRESS: at 55.82% examples, 991554 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 3 - PROGRESS: at 80.76% examples, 961975 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 3 : training on 4900563 raw words (3603556 effective words) took 3.8s, 947353 effective words/s
# INFO : EPOCH 4 - PROGRESS: at 23.05% examples, 818425 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 4 - PROGRESS: at 49.28% examples, 874733 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 4 - PROGRESS: at 75.10% examples, 895207 words/s, in_qsize 6, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 4 : training on 4900563 raw words (3604688 effective words) took 4.0s, 905808 effective words/s
# INFO : EPOCH 5 - PROGRESS: at 26.06% examples, 938307 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 5 - PROGRESS: at 54.14% examples, 958687 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 5 - PROGRESS: at 81.08% examples, 966082 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 5 : training on 4900563 raw words (3604447 effective words) took 3.7s, 972679 effective words/s
# INFO : EPOCH 6 - PROGRESS: at 26.18% examples, 946565 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 6 - PROGRESS: at 52.69% examples, 936764 words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH
words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH 94 - PROGRESS: at 55.38% examples, 982594 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 94 - PROGRESS: at 82.53% examples, 984944 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 94 : training on 4900563 raw words (3604329 effective words) took 3.6s, 989539 effective words/s
# INFO : EPOCH 95 - PROGRESS: at 26.18% examples, 946740 words/s, in_qsize 5, out_qsize 1
# INFO : EPOCH 95 - PROGRESS: at 53.25% examples, 947845 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 95 - PROGRESS: at 79.28% examples, 944754 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 95 : training on 4900563 raw words (3604412 effective words) took 3.8s, 946817 effective words/s
# INFO : EPOCH 96 - PROGRESS: at 26.51% examples, 950827 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 96 - PROGRESS: at 54.78% examples, 967683 words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH 96 - PROGRESS: at 82.53% examples, 980244 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 96 : training on 4900563 raw words (3604594 effective words) took 3.7s, 984772 effective words/s
# INFO : EPOCH 97 - PROGRESS: at 28.03% examples, 1000932 words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH 97 - PROGRESS: at 56.35% examples, 998895 words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH 97 - PROGRESS: at 83.69% examples, 995990 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 97 : training on 4900563 raw words (3604507 effective words) took 3.6s, 998709 effective words/s
# INFO : EPOCH 98 - PROGRESS: at 27.87% examples, 991228 words/s, in_qsize 6, out_qsize 0
# INFO : EPOCH 98 - PROGRESS: at 56.47% examples, 1000627 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 98 - PROGRESS: at 84.06% examples, 1001161 words/s, in_qsize 6, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 98 : training on 4900563 raw words (3604423 effective words) took 3.6s, 1001283 effective words/s
# INFO : EPOCH 99 - PROGRESS: at 27.47% examples, 987817 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 99 - PROGRESS: at 55.02% examples, 980784 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 99 - PROGRESS: at 82.33% examples, 986391 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 99 : training on 4900563 raw words (3603766 effective words) took 3.6s, 990799 effective words/s
# INFO : EPOCH 100 - PROGRESS: at 27.87% examples, 993792 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 100 - PROGRESS: at 55.38% examples, 981802 words/s, in_qsize 5, out_qsize 0
# INFO : EPOCH 100 - PROGRESS: at 82.33% examples, 982204 words/s, in_qsize 5, out_qsize 0
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 100 : training on 4900563 raw words (3603989 effective words) took 3.6s, 987626 effective words/s
# INFO : training on a 490056300 raw words (360429506 effective words) took 400.9s, 899002 effective words/s

# %%
model.docvecs.most_similar('My escape from North Korea | Hyeonseo Lee')
# Out:
# [('The family I lost in North Korea. And the family I gained | Joseph Kim',
#   0.4953937232494354),
#  ('What I learned as a prisoner in North Korea | Euna Lee',
#   0.3836573362350464),
#  ('Making peace is a marathon | May El-Khalil', 0.38031214475631714),
#  ('A boat carrying 500 refugees sunk at sea. The story of two survivors | Melissa Fleming',
#   0.3799622654914856),
#  ('Wael Ghonim: Inside the Egyptian revolution', 0.36600223183631897),
#  ('Kenichi Ebina: Hip-hop dance and a little magic', 0.3629753291606903),
#  ('Abigail Washburn: Building US-China relations ... by banjo',
#   0.34847307205200195),
#  ('How My Mind Came Back to Life — and No One Knew | Martin Pistorius | TED Talks',
#   0.34787577390670776),
#  ('Michael Anti: Behind the Great Firewall of China', 0.3474963903427124),
#  ('Barat Ali Batoor: My desperate journey with a human smuggler',
#   0.34677553176879883)]

# %%
df.head(1)
# Out:
#    average_rating               categories  \
# 0        4.729469  [Nonprofits & Activism]
#
#                                          description  dislike_count  duration  \
# 0  http://www.ted.com When German psychologist In...           14.0       830
#
#             id  like_count                                         thumbnail  \
# 0  Jc2F3-nawnI       193.0  https://i.ytimg.com/vi/Jc2F3-nawnI/hqdefault.jpg
#
#                                                title upload_date  view_count  \
# 0  Inge Missmahl brings peace to the minds of Afg...  2010-09-29       20695
#
#                                    webpage_url  \
# 0  https://www.youtube.com/watch?v=Jc2F3-nawnI
#
#                                           transcript  \
# 0  So I want to tell you a story -- an encouragin...
#
#                             similar_articles_unigram
# 0  Maira Kalman: The illustrated woman\nOne woman...

# %%
content = gensim.utils.simple_preprocess (df.iloc[0]["transcript"])

# %%
content
# Out:
# ['so',
#  'want',
#  'to',
#  'tell',
#  'you',
#  'story',
#  'an',
#  'encouraging',
#  'story',
#  'about',
#  'addressing',
#  'desperation',
#  'depression',
#  'and',
#  'despair',
#  'in',
#  'afghanistan',
#  'and',
#  'what',
#  'we',
#  'have',
#  'learned',
#  'from',
#  'it',
#  'and',
#  'how',
#  'to',
#  'help',
#  'people',
#  'to',
#  'overcome',
#  'traumatic',
#  'experiences',
#  'and',
#  'how',
#  'to',
#  'help',
#  'them',
#  'to',
#  'regain',
#  'some',
#  'confidence',
#  'in',
#  'the',
#  'time',
#  'ahead',
#  'in',
#  'the',
#  'future',
#  'and',
#  'how',
#  'to',
#  'participate',
#  'again',
#  'in',
#  'everyday',
#  'life',
#  'so',
#  'am',
#  'jungian',
#  'psychoanalyst',
#  'and',
#  'went',
#  'to',
#  'afghanistan',
#  'in',
#  'january',
#  'by',
#  'chance',
#  'on',
#  'an',
#  'assignment',
#  'for',
#  'medica',
#  'mondiale',
#  'jung',
#  'in',
#  'afghanistan',
#  'you',
#  'get',
#  'the',
#  'picture',
#  'afghanistan',
#  'is',
#  'one',
#  'of',
#  'the',
#  'poorest',
#  'countries',
#  'in',
#  'the',
#  'world',
#  'and',
#  'percent',
#  'of',
#  'the',
#  'people',
#  'are',
#  'illiterate',
#  'war',
#  'and',
#  'malnutrition',
#  'kills',
#  'people',
#  'together',
#  'with',
#  'hope',
#  'you',
#  'may',
#  'know',
#  'this',
#  'from',
#  'the',
#  'media',
#  'but',
#  'what',
#  'you',
#  'may',
#  'not',
#  'know',
#  'is',
#  'that',
#  'the',
#  'average',
#  'age',
#  'of',
#  'the',
#  'afghan',
#  'people',
#  'is',
#  'years',
#  'old',
#  'which',
#  'means',
#  'they',
#  'grow',
#  'up',
#  'in',
#  'such',
#  'an',
#  'environment',
#  'and',
#  'repeat',
#  'myself',
#  'in',
#  'years',
#  'of',
#  'war',
#  'so',
#  'this',
#  'translates',
#  'into',
#  'ongoing',
#  'violence',
#  'foreign',
#  'interests',
#  'bribery',
#  'drugs',
#  'ethnic',
#  'conflicts',
#  'bad',
#  'health',
#  'shame',
#  'fear',
#  'and',
#  'cumulative',
#  'traumatic',
#  'experiences',
#  'local',
#  'and',
#  'foreign',
#  'military',
#  'are',
#  'supposed',
#  'to',
#  'build',
#  'peace',
#  'together',
#  'with',
#  'the',
#  'donors',
#  'and',
#  'the',
#  'governmental',
#  'and',
#  'non',
#  'governmental',
#  'organizations',
#  'and',
#  'people',
#  'had',
#  'hope',
#  'yes',
#  'but',
#  'until',
#  'they',
#  'realized',
#  'their',
#  'situation',
#  'worsens',
#  'every',
#  'day',
#  'either',
#  'because',
#  'they',
#  'are',
#  'being',
#  'killed',
#  'or',
#  'because',
#  'somehow',
#  'they',
#  'are',
#  'poorer',
#  'than',
#  'eight',
#  'years',
#  'ago',
#  'one',
#  'figure',
#  'for',
#  'that',
#  'percent',
#  'of',
#  'the',
#  'children',
#  'under',
#  'the',
#  'age',
#  'of',
#  'five',
#  'years',
#  'suffer',
#  'from',
#  'malnutrition',
#  'yet',
#  'there',
#  'is',
#  'hope',
#  'one',
#  'day',
#  'man',
#  'told',
#  'me',
#  'my',
#  'future',
#  'does',
#  'not',
#  'look',
#  'brilliant',
#  'but',
#  'want',
#  'to',
#  'have',
#  'brilliant',
#  'future',
#  'for',
#  'my',
#  'son',
#  'this',
#  'is',
#  'picture',
#  'took',
#  'in',
#  'walking',
#  'on',
#  'fridays',
#  'over',
#  'the',
#  'hills',
#  'in',
#  'kabul',
#  'and',
#  'for',
#  'me',
#  'it',
#  'symbolic',
#  'picture',
#  'of',
#  'an',
#  'open',
#  'future',
#  'for',
#  'young',
#  'generation',
#  'so',
#  'doctors',
#  'prescribe',
#  'medication',
#  'and',
#  'donors',
#  'are',
#  'supposed',
#  'to',
#  'bring',
#  'peace',
#  'by',
#  'building',
#  'schools',
#  'and',
#  'roads',
#  'military',
#  'collect',
#  'weapons',
#  'and',
#  'depression',
#  'stays',
#  'intact',
#  'why',
#  'because',
#  'people',
#  'don',
#  'have',
#  'tools',
#  'to',
#  'cope',
#  'with',
#  'it',
#  'to',
#  'get',
#  'over',
#  'it',
#  'so',
#  'soon',
#  'after',
#  'my',
#  'arrival',
#  'had',
#  'confirmed',
#  'something',
#  'which',
#  'had',
#  'already',
#  'known',
#  'that',
#  'my',
#  'instruments',
#  'come',
#  'from',
#  'the',
#  'heart',
#  'of',
#  'modern',
#  'europe',
#  'yes',
#  'however',
#  'what',
#  'can',
#  'wound',
#  'us',
#  'and',
#  'our',
#  'reaction',
#  'to',
#  'those',
#  'wounds',
#  'they',
#  'are',
#  'universal',
#  'and',
#  'the',
#  'big',
#  'challenge',
#  'was',
#  'how',
#  'to',
#  'understand',
#  'the',
#  'meaning',
#  'of',
#  'the',
#  'symptom',
#  'in',
#  'this',
#  'specific',
#  'cultural',
#  'context',
#  'after',
#  'counseling',
#  'session',
#  'woman',
#  'said',
#  'to',
#  'me',
#  'because',
#  'you',
#  'have',
#  'felt',
#  'me',
#  'can',
#  'feel',
#  'myself',
#  'again',
#  'and',
#  'want',
#  'to',
#  'participate',
#  'again',
#  'in',
#  'my',
#  'family',
#  'life',
#  'this',
#  'was',
#  'very',
#  'important',
#  'because',
#  'the',
#  'family',
#  'is',
#  'central',
#  'in',
#  'afghans',
#  'social',
#  'system',
#  'no',
#  'one',
#  'can',
#  'survive',
#  'alone',
#  'and',
#  'if',
#  'people',
#  'feel',
#  'used',
#  'worthless',
#  'and',
#  'ashamed',
#  'because',
#  'something',
#  'horrible',
#  'has',
#  'happened',
#  'to',
#  'them',
#  'then',
#  'they',
#  'retreat',
#  'and',
#  'they',
#  'fall',
#  'into',
#  'social',
#  'isolation',
#  'and',
#  'they',
#  'do',
#  'not',
#  'dare',
#  'to',
#  'tell',
#  'this',
#  'evil',
#  'to',
#  'other',
#  'people',
#  'or',
#  'to',
#  'their',
#  'loved',
#  'ones',
#  'because',
#  'they',
#  'do',
#  'not',
#  'want',
#  'to',
#  'burden',
#  'them',
#  'and',
#  'very',
#  'often',
#  'violence',
#  'is',
#  'way',
#  'to',
#  'cope',
#  'with',
#  'it',
#  'traumatized',
#  'people',
#  'also',
#  'easily',
#  'lose',
#  'control',
#  'symptoms',
#  'are',
#  'hyper',
#  'arousal',
#  'and',
#  'memory',
#  'flashbacks',
#  'so',
#  'people',
#  'are',
#  'in',
#  'constant',
#  'fear',
#  'that',
#  'those',
#  'horrible',
#  'feelings',
#  'of',
#  'that',
#  'traumatic',
#  'event',
#  'might',
#  'come',
#  'back',
#  'unexpectedly',
#  'suddenly',
#  'and',
#  'they',
#  'cannot',
#  'control',
#  'it',
#  'to',
#  'compensate',
#  'this',
#  'loss',
#  'of',
#  'inner',
#  'control',
#  'they',
#  'try',
#  'to',
#  'control',
#  'the',
#  'outside',
#  'very',
#  'understandably',
#  'mostly',
#  'the',
#  'family',
#  'and',
#  'unfortunately',
#  'this',
#  'fits',
#  'very',
#  'well',
#  'into',
#  'the',
#  'traditional',
#  'side',
#  'regressive',
#  'side',
#  'repressive',
#  'side',
#  'restrictive',
#  'side',
#  'of',
#  'the',
#  'cultural',
#  'context',
#  'so',
#  'husbands',
#  'start',
#  'beating',
#  'wives',
#  'mothers',
#  'and',
#  'fathers',
#  'beat',
#  'their',
#  'children',
#  'and',
#  'afterward',
#  'they',
#  'feel',
#  'awful',
#  'they',
#  'did',
#  'not',
#  'want',
#  'to',
#  'do',
#  'this',
#  'it',
#  'just',
#  'happened',
#  'they',
#  'lost',
#  'control',
#  'the',
#  'desperate',
#  'try',
#  'to',
#  'restore',
#  'order',
#  'and',
#  'normality',
#  'and',
#  'if',
#  'we',
#  'are',
#  'not',
#  'able',
#  'to',
#  'cut',
#  'this',
#  'circle',
#  'of',
#  'violence',
#  'it',
#  'will',
#  'be',
#  'transferred',
#  'to',
#  'the',
#  'next',
#  'generation',
#  'without',
#  'doubt',
#  'and',
#  'partly',
#  'this',
#  'is',
#  'already',
#  'happening',
#  'so',
#  'everybody',
#  'needs',
#  'sense',
#  'for',
#  'the',
#  'future',
#  'and',
#  'the',
#  'afghan',
#  'sense',
#  'of',
#  'the',
#  'future',
#  'is',
#  'shattered',
#  'but',
#  'let',
#  'me',
#  'repeat',
#  'the',
#  'words',
#  'of',
#  'the',
#  'woman',
#  'because',
#  'you',
#  'have',
#  'felt',
#  'me',
#  'can',
#  'feel',
#  'myself',
#  'again',
#  'so',
#  'the',
#  'key',
#  'here',
#  'is',
#  'empathy',
#  'somebody',
#  'has',
#  'to',
#  'be',
#  'witness',
#  'to',
#  'what',
#  'has',
#  'happened',
#  'to',
#  'you',
#  'somebody',
#  'has',
#  'to',
#  'feel',
#  'how',
#  'you',
#  'felt',
#  'and',
#  'somebody',
#  'has',
#  'to',
#  'see',
#  'you',
#  'and',
#  'listen',
#  'to',
#  'you',
#  'everybody',
#  'must',
#  'be',
#  'able',
#  'to',
#  'know',
#  'what',
#  'he',
#  'or',
#  'she',
#  'has',
#  'experienced',
#  'is',
#  'true',
#  'and',
#  'this',
#  'only',
#  'goes',
#  'with',
#  'another',
#  'person',
#  'so',
#  'everybody',
#  'must',
#  'be',
#  'able',
#  'to',
#  'say',
#  'this',
#  'happened',
#  'to',
#  'me',
#  'and',
#  'it',
#  'did',
#  'this',
#  'with',
#  'me',
#  'but',
#  'able',
#  'to',
#  'live',
#  'with',
#  'it',
#  'to',
#  'cope',
#  'with',
#  'it',
#  'and',
#  'to',
#  'learn',
#  'from',
#  'it',
#  'and',
#  'want',
#  'to',
#  'engage',
#  'myself',
#  'in',
#  'the',
#  'bright',
#  'future',
#  'for',
#  'my',
#  'children',
#  'and',
#  'the',
#  'children',
#  'of',
#  'my',
#  'children',
#  'and',
#  'will',
#  'not',
#  'marry',
#  'off',
#  'my',
#  'year',
#  'old',
#  'daughter',
#  'what',
#  'happens',
#  'too',
#  'often',
#  'in',
#  'afghanistan',
#  'so',
#  'something',
#  'can',
#  'be',
#  'done',
#  'even',
#  'in',
#  'such',
#  'extreme',
#  'environments',
#  'as',
#  'afghanistan',
#  'and',
#  'started',
#  'thinking',
#  'about',
#  'counseling',
#  'program',
#  'but',
#  'of',
#  'course',
#  'needed',
#  'help',
#  'and',
#  'funds',
#  'and',
#  'one',
#  'evening',
#  'was',
#  'sitting',
#  'next',
#  'to',
#  'very',
#  'nice',
#  'gentleman',
#  'in',
#  'kabul',
#  'and',
#  'he',
#  'asked',
#  'what',
#  'thought',
#  'would',
#  'be',
#  'good',
#  'in',
#  'afghanistan',
#  'and',
#  'explained',
#  'to',
#  'him',
#  'quickly',
#  'would',
#  'train',
#  'psycho',
#  'social',
#  'counselors',
#  'would',
#  'open',
#  'centers',
#  'and',
#  'explained',
#  'to',
#  'him',
#  'why',
#  'this',
#  'man',
#  'gave',
#  'me',
#  'his',
#  'contact',
#  'details',
#  'at',
#  'the',
#  'end',
#  'of',
#  'the',
#  'evening',
#  'and',
#  'said',
#  'if',
#  'you',
#  'want',
#  'to',
#  'do',
#  'this',
#  'call',
#  'me',
#  'at',
#  'that',
#  'time',
#  'it',
#  'was',
#  'the',
#  'head',
#  'of',
#  'caritas',
#  'germany',
#  'so',
#  'was',
#  'able',
#  'to',
#  'launch',
#  'three',
#  'year',
#  'project',
#  'with',
#  'caritas',
#  'germany',
#  'and',
#  'we',
#  'trained',
#  'afghan',
#  'women',
#  'and',
#  'men',
#  'and',
#  'we',
#  'opened',
#  'counseling',
#  'centers',
#  'in',
#  'kabul',
#  'this',
#  'was',
#  'our',
#  'sign',
#  'it',
#  'hand',
#  'painted',
#  'and',
#  'we',
#  'had',
#  'all',
#  'over',
#  'kabul',
#  'eleven',
#  'thousand',
#  'people',
#  'came',
#  'more',
#  'than',
#  'that',
#  'and',
#  'percent',
#  'regained',
#  'their',
#  'lives',
#  'this',
#  'was',
#  'very',
#  'exciting',
#  'time',
#  'developing',
#  'this',
#  'with',
#  'my',
#  'wonderful',
#  'afghan',
#  'team',
#  'and',
#  'they',
#  'are',
#  'working',
#  'with',
#  'me',
#  'up',
#  'to',
#  'today',
#  'we',
#  'developed',
#  'culturally',
#  'sensitive',
#  'psycho',
#  'social',
#  'counseling',
#  'approach',
#  'so',
#  'from',
#  'up',
#  'until',
#  'today',
#  'substantial',
#  'change',
#  'and',
#  'step',
#  'forward',
#  'has',
#  'been',
#  'taking',
#  'place',
#  'the',
#  'european',
#  'union',
#  'delegation',
#  'in',
#  'kabul',
#  'came',
#  'into',
#  'this',
#  'and',
#  'hired',
#  'me',
#  'to',
#  'work',
#  'inside',
#  'the',
#  'ministry',
#  'of',
#  'public',
#  'health',
#  'to',
#  'lobby',
#  'this',
#  'approach',
#  'we',
#  'succeeded',
#  'we',
#  'revised',
#  'the',
#  'mental',
#  'health',
#  'component',
#  'of',
#  'the',
#  'primary',
#  'health',
#  ...]

# %%
new_vector = model.infer_vector(content)
sims = model.docvecs.most_similar([new_vector],topn=20)
sims
# Out:
# [('Inge Missmahl brings peace to the minds of Afghanistan',
#   0.8952376246452332),
#  ('Robert Gupta and Joshua Roman duet on "Passacaglia"', 0.42193102836608887),
#  ('Aakash Odedra: A dance in a hurricane of paper, wind and light',
#   0.41195958852767944),
#  ('Dancing with light | Quixotic Fusion', 0.4063672423362732),
#  ('Kenichi Ebina: Hip-hop dance and a little magic', 0.4048229455947876),
#  ('An 11-year-old prodigy performs old-school jazz | Joey Alexander',
#   0.40476906299591064),
#  ('An electrifying acoustic guitar performance | Rodrigo y Gabriela',
#   0.3922785818576813),
#  ('Alberto Cairo: There are no scraps of men', 0.38726067543029785),
#  ("Herbie Hancock's all-star set", 0.38103994727134705),
#  ('How I Stopped the Taliban from Shutting Down My School | Sakena Yacoobi | TED Talks',
#   0.3745068907737732),
#  ('Severine Autesserre: To solve mass violence, look to locals',
#   0.3658658266067505),
#  ("The unexpected challenges of a country's first election | Philippa Neave",
#   0.3491140604019165),
#  ('A Musical Escape Into a World of Light and Color | Kaki King | TED Talks',
#   0.34308674931526184),
#  ('What separates us from chimpanzees? | Jane Goodall', 0.3415297567844391),
#  ('Peter Eigen: How to expose the corrupt', 0.34070658683776855),
#  ('Let’s Help Refugees Thrive, Not Just Survive | Melissa Fleming | TED Talks',
#   0.3390616178512573),
#  ('Dare to Educate Afghan Girls | Shabana Basij-Rasikh | TED Talks',
#   0.33656537532806396),
#  ('The Chilling Aftershock of a Brush with Death | Jean-Paul Mari | TED Talks',
#   0.3329525589942932),
#  ('Incredible high school musicians from Venezuela! | Gustavo Dudamel',
#   0.33140772581100464),
#  ('The surprising way groups like ISIS stay in power | Benedetta Berti',
#   0.32770708203315735)]
